# %%
import numpy as np
import pandas as pd
import gc
import os
import matplotlib.pyplot as plt
import polars as pl
from sklearn.metrics import mean_squared_error, mean_absolute_error
from joblib import Parallel, delayed
from more_itertools import chunked
from functools import reduce
from typing import List
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import pandas as pd
import joblib
import os
import torch.nn as nn

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# False
# 0
# No GPU
# /opt/conda/lib/python3.10/site-packages/torch/cuda/__init__.py:628: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
df_full = pd.read_parquet('./data/product_train_val_NN_TORCH.parquet', engine='fastparquet')

# %%
# Separar conjuntos
df_train = df_full[df_full['PERIODO'] <= 201909].copy()
df_val = df_full[(df_full['PERIODO'] == 201910)].copy()
df_pred = df_full[df_full['PERIODO'] == 201912].copy()
del df_full
gc.collect()
# Out:
# 20

# %%
import joblib

target_col = 'CLASE_LOG1P_Z'
cat_cols = ['ID_CAT1', 'ID_CAT2', 'ID_CAT3', 'ID_BRAND', 'SKU_SIZE', 'MES_PROBLEMATICO', 'PRODUCT_RANK_BIN', 
            'IS_FEBRERO', 'ESTOY_PREDICIENDO_FEBRERO', 'CAIDA_ABRUPTA']
label_encoders = {}

# Cargar los encoders entrenados
for col in cat_cols:
    le = joblib.load(f'encoders/{col}_encoder.pkl')
    label_encoders[col] = le

    # Transformar los datasets (train, val, pred) usando ese encoder
    for df in [df_train, df_val, df_pred]:
        df[col] = df[col].map(lambda x: le.transform([x])[0] if x in le.classes_ else 0)

# Definir embedding_sizes (lo mejor es usar el encoder para ver la cantidad de clases)
embedding_sizes = [
    (len(label_encoders[col].classes_) + 1, min(50, (len(label_encoders[col].classes_) + 1) // 2))
    for col in cat_cols
]

# Excluir columnas que no deben ir al modelo
excluir = ['PERIODO', 'CUSTOMER_ID', 'PRODUCT_ID', 'CLASE_LOG1P_Z', 'ORDINAL']
feature_cols = [col for col in df.columns if col not in excluir and col not in cat_cols]

# %%
WINDOW_SIZE = 12
PREDICT_HORIZON = 2

X_seq_train, y_seq_train, prod_ids_train = [], [], []

for prod, df_prod in df_train.groupby('PRODUCT_ID'):
    df_prod = df_prod.sort_values('PERIODO')
    for i in range(len(df_prod) - WINDOW_SIZE - PREDICT_HORIZON):
        seq = df_prod.iloc[i:i+WINDOW_SIZE][feature_cols].values
        target = df_prod.iloc[i+WINDOW_SIZE+PREDICT_HORIZON][target_col]
        X_seq_train.append(seq)
        y_seq_train.append(target)
        prod_ids_train.append(prod)

X_seq_train = np.array(X_seq_train)
y_seq_train = np.array(y_seq_train)
prod_ids_train = np.array(prod_ids_train)

# %%
X_seq_val, y_seq_val, prod_ids_val = [], [], []

for prod, df_prod in df_val.groupby('PRODUCT_ID'):
    df_prod = df_prod.sort_values('PERIODO')
    for i in range(len(df_prod) - WINDOW_SIZE - PREDICT_HORIZON):
        seq = df_prod.iloc[i:i+WINDOW_SIZE][feature_cols].values
        target = df_prod.iloc[i+WINDOW_SIZE+PREDICT_HORIZON][target_col]
        X_seq_val.append(seq)
        y_seq_val.append(target)
        prod_ids_val.append(prod)

X_seq_val = np.array(X_seq_val)
y_seq_val = np.array(y_seq_val)
prod_ids_val = np.array(prod_ids_val)

# %%
for prod, df_prod in df_pred.groupby('PRODUCT_ID'):
    df_hist = pd.concat([
        df_train[df_train['PRODUCT_ID'] == prod],
        df_val[df_val['PRODUCT_ID'] == prod],
        df_prod
    ]).sort_values('PERIODO')
    idxs = df_hist.index[df_hist['PERIODO'] == 201910].tolist()
    if not idxs:
        continue
    idx = idxs[0]
    start = idx - WINDOW_SIZE + 1
    if start < 0:
        continue
    seq = df_hist.iloc[start:idx+1][feature_cols].values
    # --- CHEQUEO ---
    if seq.shape != (WINDOW_SIZE, len(feature_cols)):
        print(f"Producto {prod} - shape inválido: {seq.shape}, saltando")
        continue
    X_seq_pred.append(seq)
    prod_ids_pred.append(prod)
# Out:
# Producto 20002 - shape inválido: (8, 211), saltando
# Producto 20003 - shape inválido: (0, 211), saltando
# Producto 20004 - shape inválido: (0, 211), saltando
# Producto 20005 - shape inválido: (0, 211), saltando
# Producto 20006 - shape inválido: (0, 211), saltando
# Producto 20007 - shape inválido: (0, 211), saltando
# Producto 20008 - shape inválido: (0, 211), saltando
# Producto 20009 - shape inválido: (0, 211), saltando
# Producto 20010 - shape inválido: (0, 211), saltando
# Producto 20011 - shape inválido: (0, 211), saltando
# Producto 20012 - shape inválido: (0, 211), saltando
# Producto 20013 - shape inválido: (0, 211), saltando
# Producto 20014 - shape inválido: (0, 211), saltando
# Producto 20015 - shape inválido: (0, 211), saltando
# Producto 20016 - shape inválido: (0, 211), saltando
# Producto 20017 - shape inválido: (0, 211), saltando
# Producto 20018 - shape inválido: (0, 211), saltando
# Producto 20019 - shape inválido: (0, 211), saltando
# Producto 20020 - shape inválido: (0, 211), saltando
# Producto 20021 - shape inválido: (0, 211), saltando
# Producto 20022 - shape inválido: (0, 211), saltando
# Producto 20023 - shape inválido: (0, 211), saltando
# Producto 20024 - shape inválido: (0, 211), saltando
# Producto 20025 - shape inválido: (0, 211), saltando
# Producto 20026 - shape inválido: (0, 211), saltando
# Producto 20027 - shape inválido: (0, 211), saltando
# Producto 20028 - shape inválido: (0, 211), saltando
# Producto 20029 - shape inválido: (0, 211), saltando
# Producto 20030 - shape inválido: (0, 211), saltando
# Producto 20031 - shape inválido: (0, 211), saltando
# Producto 20032 - shape inválido: (0, 211), saltando
# Producto 20033 - shape inválido: (0, 211), saltando
# Producto 20035 - shape inválido: (0, 211), saltando
# Producto 20037 - shape inválido: (0, 211), saltando
# Producto 20038 - shape inválido: (0, 211), saltando
# Producto 20039 - shape inválido: (0, 211), saltando
# Producto 20041 - shape inválido: (0, 211), saltando
# Producto 20042 - shape inválido: (0, 211), saltando
# Producto 20043 - shape inválido: (0, 211), saltando
# Producto 20044 - shape inválido: (0, 211), saltando
# Producto 20045 - shape inválido: (0, 211), saltando
# Producto 20046 - shape inválido: (0, 211), saltando
# Producto 20047 - shape inválido: (0, 211), saltando
# Producto 20049 - shape inválido: (0, 211), saltando
# Producto 20050 - shape inválido: (0, 211), saltando
# Producto 20051 - shape inválido: (0, 211), saltando
# Producto 20052 - shape inválido: (0, 211), saltando
# Producto 20053 - shape inválido: (0, 211), saltando
# Producto 20054 - shape inválido: (0, 211), saltando
# Producto 20055 - shape inválido: (0, 211), saltando
# Producto 20056 - shape inválido: (0, 211), saltando
# Producto 20057 - shape inválido: (0, 211), saltando
# Producto 20058 - shape inválido: (0, 211), saltando
# Producto 20059 - shape inválido: (0, 211), saltando
# Producto 20061 - shape inválido: (0, 211), saltando
# Producto 20062 - shape inválido: (0, 211), saltando
# Producto 20063 - shape inválido: (0, 211), saltando
# Producto 20065 - shape inválido: (0, 211), saltando
# Producto 20066 - shape inválido: (0, 211), saltando
# Producto 20067 - shape inválido: (0, 211), saltando
# Producto 20068 - shape inválido: (0, 211), saltando
# Producto 20069 - shape inválido: (0, 211), saltando
# Producto 20070 - shape inválido: (0, 211), saltando
# Producto 20071 - shape inválido: (0, 211), saltando
# Producto 20072 - shape inválido: (0, 211), saltando
# Producto 20073 - shape inválido: (0, 211), saltando
# Producto 20074 - shape inválido: (0, 211), saltando
# Producto 20075 - shape inválido: (0, 211), saltando
# Producto 20076 - shape inválido: (0, 211), saltando
# Producto 20077 - shape inválido: (0, 211), saltando
# Producto 20079 - shape inválido: (0, 211), saltando
# Producto 20080 - shape inválido: (0, 211), saltando
# Producto 20081 - shape inválido: (0, 211), saltando
# Producto 20082 - shape inválido: (0, 211), saltando
# Producto 20084 - shape inválido: (0, 211), saltando
# Producto 20085 - shape inválido: (0, 211), saltando
# Producto 20086 - shape inválido: (0, 211), saltando
# Producto 20087 - shape inválido: (0, 211), saltando
# Producto 20089 - shape inválido: (0, 211), saltando
# Producto 20090 - shape inválido: (0, 211), saltando
# Producto 20091 - shape inválido: (0, 211), saltando
# Producto 20092 - shape inválido: (0, 211), saltando
# Producto 20093 - shape inválido: (0, 211), saltando
# Producto 20094 - shape inválido: (0, 211), saltando
# Producto 20095 - shape inválido: (0, 211), saltando
# Producto 20096 - shape inválido: (0, 211), saltando
# Producto 20097 - shape inválido: (0, 211), saltando
# Producto 20099 - shape inválido: (0, 211), saltando
# Producto 20100 - shape inválido: (0, 211), saltando
# Producto 20101 - shape inválido: (0, 211), saltando
# Producto 20102 - shape inválido: (0, 211), saltando
# Producto 20103 - shape inválido: (0, 211), saltando
# Producto 20106 - shape inválido: (0, 211), saltando
# Producto 20107 - shape inválido: (0, 211), saltando
# Producto 20108 - shape inválido: (0, 211), saltando
# Producto 20109 - shape inválido: (0, 211), saltando
# Producto 20111 - shape inválido: (0, 211), saltando
# Producto 20112 - shape inválido: (0, 211), saltando
# Producto 20114 - shape inválido: (0, 211), saltando
# Producto 20116 - shape inválido: (0, 211), saltando
# Producto 20117 - shape inválido: (0, 211), saltando
# Producto 20118 - shape inválido: (0, 211), saltando
# Producto 20119 - shape inválido: (0, 211), saltando
# Producto 20120 - shape inválido: (0, 211), saltando
# Producto 20121 - shape inválido: (0, 211), saltando
# Producto 20122 - shape inválido: (0, 211), saltando
# Producto 20123 - shape inválido: (0, 211), saltando
# Producto 20124 - shape inválido: (0, 211), saltando
# Producto 20125 - shape inválido: (0, 211), saltando
# Producto 20126 - shape inválido: (0, 211), saltando
# Producto 20127 - shape inválido: (0, 211), saltando
# Producto 20129 - shape inválido: (0, 211), saltando
# Producto 20130 - shape inválido: (0, 211), saltando
# Producto 20132 - shape inválido: (0, 211), saltando
# Producto 20133 - shape inválido: (0, 211), saltando
# Producto 20134 - shape inválido: (0, 211), saltando
# Producto 20135 - shape inválido: (0, 211), saltando
# Producto 20137 - shape inválido: (0, 211), saltando
# Producto 20138 - shape inválido: (0, 211), saltando
# Producto 20139 - shape inválido: (0, 211), saltando
# Producto 20140 - shape inválido: (0, 211), saltando
# Producto 20142 - shape inválido: (0, 211), saltando
# Producto 20143 - shape inválido: (0, 211), saltando
# Producto 20144 - shape inválido: (0, 211), saltando
# Producto 20145 - shape inválido: (0, 211), saltando
# Producto 20146 - shape inválido: (0, 211), saltando
# Producto 20148 - shape inválido: (0, 211), saltando
# Producto 20150 - shape inválido: (0, 211), saltando
# Producto 20151 - shape inválido: (0, 211), saltando
# Producto 20152 - shape inválido: (0, 211), saltando
# Producto 20153 - shape inválido: (0, 211), saltando
# Producto 20155 - shape inválido: (0, 211), saltando
# Producto 20157 - shape inválido: (0, 211), saltando
# Producto 20158 - shape inválido: (0, 211), saltando
# Producto 20159 - shape inválido: (0, 211), saltando
# Producto 20160 - shape inválido: (0, 211), saltando
# Producto 20161 - shape inválido: (0, 211), saltando
# Producto 20162 - shape inválido: (0, 211), saltando
# Producto 20164 - shape inválido: (0, 211), saltando
# Producto 20166 - shape inválido: (0, 211), saltando
# Producto 20167 - shape inválido: (0, 211), saltando
# Producto 20168 - shape inválido: (0, 211), saltando
# Producto 20170 - shape inválido: (0, 211), saltando
# Producto 20174 - shape inválido: (0, 211), saltando
# Producto 20175 - shape inválido: (0, 211), saltando
# Producto 20176 - shape inválido: (0, 211), saltando
# Producto 20177 - shape inválido: (0, 211), saltando
# Producto 20179 - shape inválido: (0, 211), saltando
# Producto 20180 - shape inválido: (0, 211), saltando
# Producto 20181 - shape inválido: (0, 211), saltando
# Producto 20182 - shape inválido: (0, 211), saltando
# Producto 20183 - shape inválido: (0, 211), saltando
# Producto 20184 - shape inválido: (0, 211), saltando
# Producto 20187 - shape inválido: (0, 211), saltando
# Producto 20188 - shape inválido: (0, 211), saltando
# Producto 20189 - shape inválido: (0, 211), saltando
# Producto 20192 - shape inválido: (0, 211), saltando
# Producto 20193 - shape inválido: (0, 211), saltando
# Producto 20196 - shape inválido: (0, 211), saltando
# Producto 20197 - shape inválido: (0, 211), saltando
# Producto 20198 - shape inválido: (0, 211), saltando
# Producto 20200 - shape inválido: (0, 211), saltando
# Producto 20201 - shape inválido: (0, 211), saltando
# Producto 20202 - shape inválido: (0, 211), saltando
# Producto 20203 - shape inválido: (0, 211), saltando
# Producto 20205 - shape inválido: (0, 211), saltando
# Producto 20206 - shape inválido: (0, 211), saltando
# Producto 20207 - shape inválido: (0, 211), saltando
# Producto 20208 - shape inválido: (0, 211), saltando
# Producto 20209 - shape inválido: (0, 211), saltando
# Producto 20210 - shape inválido: (0, 211), saltando
# Producto 20211 - shape inválido: (0, 211), saltando
# Producto 20212 - shape inválido: (0, 211), saltando
# Producto 20213 - shape inválido: (0, 211), saltando
# Producto 20215 - shape inválido: (0, 211), saltando
# Producto 20216 - shape inválido: (0, 211), saltando
# Producto 20218 - shape inválido: (0, 211), saltando
# Producto 20219 - shape inválido: (0, 211), saltando
# Producto 20220 - shape inválido: (0, 211), saltando
# Producto 20222 - shape inválido: (0, 211), saltando
# Producto 20224 - shape inválido: (0, 211), saltando
# Producto 20225 - shape inválido: (0, 211), saltando
# Producto 20226 - shape inválido: (0, 211), saltando
# Producto 20227 - shape inválido: (0, 211), saltando
# Producto 20228 - shape inválido: (0, 211), saltando
# Producto 20230 - shape inválido: (0, 211), saltando
# Producto 20231 - shape inválido: (0, 211), saltando
# Producto 20232 - shape inválido: (0, 211), saltando
# Producto 20233 - shape inválido: (0, 211), saltando
# Producto 20234 - shape inválido: (0, 211), saltando
# Producto 20235 - shape inválido: (0, 211), saltando
# Producto 20236 - shape inválido: (0, 211), saltando
# Producto 20237 - shape inválido: (0, 211), saltando
# Producto 20238 - shape inválido: (0, 211), saltando
# Producto 20239 - shape inválido: (0, 211), saltando
# Producto 20240 - shape inválido: (0, 211), saltando
# Producto 20241 - shape inválido: (0, 211), saltando
# Producto 20242 - shape inválido: (0, 211), saltando
# Producto 20244 - shape inválido: (0, 211), saltando
# Producto 20246 - shape inválido: (0, 211), saltando
# Producto 20249 - shape inválido: (0, 211), saltando
# Producto 20251 - shape inválido: (0, 211), saltando
# Producto 20252 - shape inválido: (0, 211), saltando
# Producto 20253 - shape inválido: (0, 211), saltando
# Producto 20254 - shape inválido: (0, 211), saltando
# Producto 20255 - shape inválido: (0, 211), saltando
# Producto 20256 - shape inválido: (0, 211), saltando
# Producto 20257 - shape inválido: (0, 211), saltando
# Producto 20259 - shape inválido: (0, 211), saltando
# Producto 20261 - shape inválido: (0, 211), saltando
# Producto 20262 - shape inválido: (0, 211), saltando
# Producto 20263 - shape inválido: (0, 211), saltando
# Producto 20264 - shape inválido: (0, 211), saltando
# Producto 20265 - shape inválido: (0, 211), saltando
# Producto 20266 - shape inválido: (0, 211), saltando
# Producto 20267 - shape inválido: (0, 211), saltando
# Producto 20268 - shape inválido: (0, 211), saltando
# Producto 20269 - shape inválido: (0, 211), saltando
# Producto 20270 - shape inválido: (0, 211), saltando
# Producto 20271 - shape inválido: (0, 211), saltando
# Producto 20272 - shape inválido: (0, 211), saltando
# Producto 20273 - shape inválido: (0, 211), saltando
# Producto 20275 - shape inválido: (0, 211), saltando
# Producto 20276 - shape inválido: (0, 211), saltando
# Producto 20277 - shape inválido: (0, 211), saltando
# Producto 20278 - shape inválido: (0, 211), saltando
# Producto 20280 - shape inválido: (0, 211), saltando
# Producto 20281 - shape inválido: (0, 211), saltando
# Producto 20282 - shape inválido: (0, 211), saltando
# Producto 20283 - shape inválido: (0, 211), saltando
# Producto 20284 - shape inválido: (0, 211), saltando
# Producto 20285 - shape inválido: (0, 211), saltando
# Producto 20286 - shape inválido: (0, 211), saltando
# Producto 20288 - shape inválido: (0, 211), saltando
# Producto 20289 - shape inválido: (0, 211), saltando
# Producto 20290 - shape inválido: (0, 211), saltando
# Producto 20291 - shape inválido: (0, 211), saltando
# Producto 20292 - shape inválido: (0, 211), saltando
# Producto 20295 - shape inválido: (0, 211), saltando
# Producto 20296 - shape inválido: (0, 211), saltando
# Producto 20297 - shape inválido: (0, 211), saltando
# Producto 20298 - shape inválido: (0, 211), saltando
# Producto 20299 - shape inválido: (0, 211), saltando
# Producto 20300 - shape inválido: (0, 211), saltando
# Producto 20301 - shape inválido: (0, 211), saltando
# Producto 20302 - shape inválido: (0, 211), saltando
# Producto 20303 - shape inválido: (0, 211), saltando
# Producto 20304 - shape inválido: (0, 211), saltando
# Producto 20305 - shape inválido: (0, 211), saltando
# Producto 20306 - shape inválido: (0, 211), saltando
# Producto 20307 - shape inválido: (0, 211), saltando
# Producto 20309 - shape inválido: (0, 211), saltando
# Producto 20310 - shape inválido: (0, 211), saltando
# Producto 20311 - shape inválido: (0, 211), saltando
# Producto 20313 - shape inválido: (0, 211), saltando
# Producto 20314 - shape inválido: (0, 211), saltando
# Producto 20315 - shape inválido: (0, 211), saltando
# Producto 20316 - shape inválido: (0, 211), saltando
# Producto 20317 - shape inválido: (0, 211), saltando
# Producto 20319 - shape inválido: (0, 211), saltando
# Producto 20320 - shape inválido: (0, 211), saltando
# Producto 20321 - shape inválido: (0, 211), saltando
# Producto 20322 - shape inválido: (0, 211), saltando
# Producto 20323 - shape inválido: (0, 211), saltando
# Producto 20324 - shape inválido: (0, 211), saltando
# Producto 20325 - shape inválido: (0, 211), saltando
# Producto 20326 - shape inválido: (0, 211), saltando
# Producto 20327 - shape inválido: (0, 211), saltando
# Producto 20328 - shape inválido: (0, 211), saltando
# Producto 20329 - shape inválido: (0, 211), saltando
# Producto 20330 - shape inválido: (0, 211), saltando
# Producto 20332 - shape inválido: (0, 211), saltando
# Producto 20334 - shape inválido: (0, 211), saltando
# Producto 20335 - shape inválido: (0, 211), saltando
# Producto 20336 - shape inválido: (0, 211), saltando
# Producto 20337 - shape inválido: (0, 211), saltando
# Producto 20338 - shape inválido: (0, 211), saltando
# Producto 20340 - shape inválido: (0, 211), saltando
# Producto 20341 - shape inválido: (0, 211), saltando
# Producto 20342 - shape inválido: (0, 211), saltando
# Producto 20343 - shape inválido: (0, 211), saltando
# Producto 20344 - shape inválido: (0, 211), saltando
# Producto 20346 - shape inválido: (0, 211), saltando
# Producto 20348 - shape inválido: (0, 211), saltando
# Producto 20349 - shape inválido: (0, 211), saltando
# Producto 20350 - shape inválido: (0, 211), saltando
# Producto 20351 - shape inválido: (0, 211), saltando
# Producto 20352 - shape inválido: (0, 211), saltando
# Producto 20353 - shape inválido: (0, 211), saltando
# Producto 20354 - shape inválido: (0, 211), saltando
# Producto 20355 - shape inválido: (0, 211), saltando
# Producto 20356 - shape inválido: (0, 211), saltando
# Producto 20357 - shape inválido: (0, 211), saltando
# Producto 20358 - shape inválido: (0, 211), saltando
# Producto 20359 - shape inválido: (0, 211), saltando
# Producto 20361 - shape inválido: (0, 211), saltando
# Producto 20362 - shape inválido: (0, 211), saltando
# Producto 20364 - shape inválido: (0, 211), saltando
# Producto 20365 - shape inválido: (0, 211), saltando
# Producto 20366 - shape inválido: (0, 211), saltando
# Producto 20367 - shape inválido: (0, 211), saltando
# Producto 20368 - shape inválido: (0, 211), saltando
# Producto 20372 - shape inválido: (0, 211), saltando
# Producto 20375 - shape inválido: (0, 211), saltando
# Producto 20377 - shape inválido: (0, 211), saltando
# Producto 20378 - shape inválido: (0, 211), saltando
# Producto 20379 - shape inválido: (0, 211), saltando
# Producto 20380 - shape inválido: (0, 211), saltando
# Producto 20381 - shape inválido: (0, 211), saltando
# Producto 20382 - shape inválido: (0, 211), saltando
# Producto 20383 - shape inválido: (0, 211), saltando
# Producto 20384 - shape inválido: (0, 211), saltando
# Producto 20385 - shape inválido: (0, 211), saltando
# Producto 20386 - shape inválido: (0, 211), saltando
# Producto 20387 - shape inválido: (0, 211), saltando
# Producto 20388 - shape inválido: (0, 211), saltando
# Producto 20389 - shape inválido: (0, 211), saltando
# Producto 20390 - shape inválido: (0, 211), saltando
# Producto 20395 - shape inválido: (0, 211), saltando
# Producto 20396 - shape inválido: (0, 211), saltando
# Producto 20398 - shape inválido: (0, 211), saltando
# Producto 20400 - shape inválido: (0, 211), saltando
# Producto 20401 - shape inválido: (0, 211), saltando
# Producto 20402 - shape inválido: (0, 211), saltando
# Producto 20403 - shape inválido: (0, 211), saltando
# Producto 20404 - shape inválido: (0, 211), saltando
# Producto 20406 - shape inválido: (0, 211), saltando
# Producto 20407 - shape inválido: (0, 211), saltando
# Producto 20408 - shape inválido: (0, 211), saltando
# Producto 20409 - shape inválido: (0, 211), saltando
# Producto 20410 - shape inválido: (0, 211), saltando
# Producto 20411 - shape inválido: (0, 211), saltando
# Producto 20414 - shape inválido: (0, 211), saltando
# Producto 20415 - shape inválido: (0, 211), saltando
# Producto 20416 - shape inválido: (0, 211), saltando
# Producto 20417 - shape inválido: (0, 211), saltando
# Producto 20418 - shape inválido: (0, 211), saltando
# Producto 20419 - shape inválido: (0, 211), saltando
# Producto 20421 - shape inválido: (0, 211), saltando
# Producto 20422 - shape inválido: (0, 211), saltando
# Producto 20424 - shape inválido: (0, 211), saltando
# Producto 20426 - shape inválido: (0, 211), saltando
# Producto 20428 - shape inválido: (0, 211), saltando
# Producto 20429 - shape inválido: (0, 211), saltando
# Producto 20432 - shape inválido: (0, 211), saltando
# Producto 20433 - shape inválido: (0, 211), saltando
# Producto 20434 - shape inválido: (0, 211), saltando
# Producto 20438 - shape inválido: (0, 211), saltando
# Producto 20440 - shape inválido: (0, 211), saltando
# Producto 20442 - shape inválido: (0, 211), saltando
# Producto 20443 - shape inválido: (0, 211), saltando
# Producto 20447 - shape inválido: (0, 211), saltando
# Producto 20449 - shape inválido: (0, 211), saltando
# Producto 20450 - shape inválido: (0, 211), saltando
# Producto 20453 - shape inválido: (0, 211), saltando
# Producto 20456 - shape inválido: (0, 211), saltando
# Producto 20458 - shape inválido: (0, 211), saltando
# Producto 20459 - shape inválido: (0, 211), saltando
# Producto 20460 - shape inválido: (0, 211), saltando
# Producto 20463 - shape inválido: (0, 211), saltando
# Producto 20464 - shape inválido: (0, 211), saltando
# Producto 20465 - shape inválido: (0, 211), saltando
# Producto 20466 - shape inválido: (0, 211), saltando
# Producto 20469 - shape inválido: (0, 211), saltando
# Producto 20470 - shape inválido: (0, 211), saltando
# Producto 20473 - shape inválido: (0, 211), saltando
# Producto 20474 - shape inválido: (0, 211), saltando
# Producto 20476 - shape inválido: (0, 211), saltando
# Producto 20477 - shape inválido: (0, 211), saltando
# Producto 20478 - shape inválido: (0, 211), saltando
# Producto 20479 - shape inválido: (0, 211), saltando
# Producto 20480 - shape inválido: (0, 211), saltando
# Producto 20481 - shape inválido: (0, 211), saltando
# Producto 20482 - shape inválido: (0, 211), saltando
# Producto 20483 - shape inválido: (0, 211), saltando
# Producto 20484 - shape inválido: (0, 211), saltando
# Producto 20488 - shape inválido: (0, 211), saltando
# Producto 20490 - shape inválido: (0, 211), saltando
# Producto 20491 - shape inválido: (0, 211), saltando
# Producto 20495 - shape inválido: (0, 211), saltando
# Producto 20496 - shape inválido: (0, 211), saltando
# Producto 20497 - shape inválido: (0, 211), saltando
# Producto 20500 - shape inválido: (0, 211), saltando
# Producto 20502 - shape inválido: (0, 211), saltando
# Producto 20503 - shape inválido: (0, 211), saltando
# Producto 20505 - shape inválido: (0, 211), saltando
# Producto 20508 - shape inválido: (0, 211), saltando
# Producto 20509 - shape inválido: (0, 211), saltando
# Producto 20510 - shape inválido: (0, 211), saltando
# Producto 20513 - shape inválido: (0, 211), saltando
# Producto 20514 - shape inválido: (0, 211), saltando
# Producto 20517 - shape inválido: (0, 211), saltando
# Producto 20520 - shape inválido: (0, 211), saltando
# Producto 20521 - shape inválido: (0, 211), saltando
# Producto 20522 - shape inválido: (0, 211), saltando
# Producto 20523 - shape inválido: (0, 211), saltando
# Producto 20524 - shape inválido: (0, 211), saltando
# Producto 20525 - shape inválido: (0, 211), saltando
# Producto 20526 - shape inválido: (0, 211), saltando
# Producto 20527 - shape inválido: (0, 211), saltando
# Producto 20530 - shape inválido: (0, 211), saltando
# Producto 20531 - shape inválido: (0, 211), saltando
# Producto 20532 - shape inválido: (0, 211), saltando
# Producto 20536 - shape inválido: (0, 211), saltando
# Producto 20537 - shape inválido: (0, 211), saltando
# Producto 20538 - shape inválido: (0, 211), saltando
# Producto 20539 - shape inválido: (0, 211), saltando
# Producto 20540 - shape inválido: (0, 211), saltando
# Producto 20541 - shape inválido: (0, 211), saltando
# Producto 20542 - shape inválido: (0, 211), saltando
# Producto 20544 - shape inválido: (0, 211), saltando
# Producto 20547 - shape inválido: (0, 211), saltando
# Producto 20548 - shape inválido: (0, 211), saltando
# Producto 20549 - shape inválido: (0, 211), saltando
# Producto 20551 - shape inválido: (0, 211), saltando
# Producto 20552 - shape inválido: (0, 211), saltando
# Producto 20553 - shape inválido: (0, 211), saltando
# Producto 20555 - shape inválido: (0, 211), saltando
# Producto 20558 - shape inválido: (0, 211), saltando
# Producto 20559 - shape inválido: (0, 211), saltando
# Producto 20560 - shape inválido: (0, 211), saltando
# Producto 20561 - shape inválido: (0, 211), saltando
# Producto 20563 - shape inválido: (0, 211), saltando
# Producto 20565 - shape inválido: (0, 211), saltando
# Producto 20567 - shape inválido: (0, 211), saltando
# Producto 20568 - shape inválido: (0, 211), saltando
# Producto 20569 - shape inválido: (0, 211), saltando
# Producto 20570 - shape inválido: (0, 211), saltando
# Producto 20571 - shape inválido: (0, 211), saltando
# Producto 20572 - shape inválido: (0, 211), saltando
# Producto 20574 - shape inválido: (0, 211), saltando
# Producto 20575 - shape inválido: (0, 211), saltando
# Producto 20576 - shape inválido: (0, 211), saltando
# Producto 20577 - shape inválido: (0, 211), saltando
# Producto 20578 - shape inválido: (0, 211), saltando
# Producto 20579 - shape inválido: (0, 211), saltando
# Producto 20580 - shape inválido: (0, 211), saltando
# Producto 20583 - shape inválido: (0, 211), saltando
# Producto 20585 - shape inválido: (0, 211), saltando
# Producto 20586 - shape inválido: (0, 211), saltando
# Producto 20588 - shape inválido: (0, 211), saltando
# Producto 20589 - shape inválido: (0, 211), saltando
# Producto 20592 - shape inválido: (0, 211), saltando
# Producto 20593 - shape inválido: (0, 211), saltando
# Producto 20596 - shape inválido: (0, 211), saltando
# Producto 20597 - shape inválido: (0, 211), saltando
# Producto 20599 - shape inválido: (0, 211), saltando
# Producto 20600 - shape inválido: (0, 211), saltando
# Producto 20601 - shape inválido: (0, 211), saltando
# Producto 20602 - shape inválido: (0, 211), saltando
# Producto 20603 - shape inválido: (0, 211), saltando
# Producto 20604 - shape inválido: (0, 211), saltando
# Producto 20605 - shape inválido: (0, 211), saltando
# Producto 20606 - shape inválido: (0, 211), saltando
# Producto 20609 - shape inválido: (0, 211), saltando
# Producto 20611 - shape inválido: (0, 211), saltando
# Producto 20612 - shape inválido: (0, 211), saltando
# Producto 20614 - shape inválido: (0, 211), saltando
# Producto 20615 - shape inválido: (0, 211), saltando
# Producto 20617 - shape inválido: (0, 211), saltando
# Producto 20620 - shape inválido: (0, 211), saltando
# Producto 20621 - shape inválido: (0, 211), saltando
# Producto 20622 - shape inválido: (0, 211), saltando
# Producto 20623 - shape inválido: (0, 211), saltando
# Producto 20624 - shape inválido: (0, 211), saltando
# Producto 20627 - shape inválido: (0, 211), saltando
# Producto 20628 - shape inválido: (0, 211), saltando
# Producto 20629 - shape inválido: (0, 211), saltando
# Producto 20632 - shape inválido: (0, 211), saltando
# Producto 20633 - shape inválido: (0, 211), saltando
# Producto 20636 - shape inválido: (0, 211), saltando
# Producto 20637 - shape inválido: (0, 211), saltando
# Producto 20638 - shape inválido: (0, 211), saltando
# Producto 20639 - shape inválido: (0, 211), saltando
# Producto 20640 - shape inválido: (0, 211), saltando
# Producto 20641 - shape inválido: (0, 211), saltando
# Producto 20642 - shape inválido: (0, 211), saltando
# Producto 20644 - shape inválido: (0, 211), saltando
# Producto 20646 - shape inválido: (0, 211), saltando
# Producto 20647 - shape inválido: (0, 211), saltando
# Producto 20649 - shape inválido: (0, 211), saltando
# Producto 20651 - shape inválido: (0, 211), saltando
# Producto 20652 - shape inválido: (0, 211), saltando
# Producto 20653 - shape inválido: (0, 211), saltando
# Producto 20654 - shape inválido: (0, 211), saltando
# Producto 20655 - shape inválido: (0, 211), saltando
# Producto 20657 - shape inválido: (0, 211), saltando
# Producto 20658 - shape inválido: (0, 211), saltando
# Producto 20659 - shape inválido: (0, 211), saltando
# Producto 20660 - shape inválido: (0, 211), saltando
# Producto 20661 - shape inválido: (0, 211), saltando
# Producto 20662 - shape inválido: (0, 211), saltando
# Producto 20663 - shape inválido: (0, 211), saltando
# Producto 20664 - shape inválido: (0, 211), saltando
# Producto 20666 - shape inválido: (0, 211), saltando
# Producto 20667 - shape inválido: (0, 211), saltando
# Producto 20670 - shape inválido: (0, 211), saltando
# Producto 20672 - shape inválido: (0, 211), saltando
# Producto 20673 - shape inválido: (0, 211), saltando
# Producto 20674 - shape inválido: (0, 211), saltando
# Producto 20676 - shape inválido: (0, 211), saltando
# Producto 20677 - shape inválido: (0, 211), saltando
# Producto 20678 - shape inválido: (0, 211), saltando
# Producto 20679 - shape inválido: (0, 211), saltando
# Producto 20680 - shape inválido: (0, 211), saltando
# Producto 20681 - shape inválido: (0, 211), saltando
# Producto 20682 - shape inválido: (0, 211), saltando
# Producto 20684 - shape inválido: (0, 211), saltando
# Producto 20685 - shape inválido: (0, 211), saltando
# Producto 20686 - shape inválido: (0, 211), saltando
# Producto 20689 - shape inválido: (0, 211), saltando
# Producto 20691 - shape inválido: (0, 211), saltando
# Producto 20693 - shape inválido: (0, 211), saltando
# Producto 20694 - shape inválido: (0, 211), saltando
# Producto 20696 - shape inválido: (0, 211), saltando
# Producto 20697 - shape inválido: (0, 211), saltando
# Producto 20699 - shape inválido: (0, 211), saltando
# Producto 20700 - shape inválido: (0, 211), saltando
# Producto 20701 - shape inválido: (0, 211), saltando
# Producto 20702 - shape inválido: (0, 211), saltando
# Producto 20703 - shape inválido: (0, 211), saltando
# Producto 20705 - shape inválido: (0, 211), saltando
# Producto 20706 - shape inválido: (0, 211), saltando
# Producto 20708 - shape inválido: (0, 211), saltando
# Producto 20709 - shape inválido: (0, 211), saltando
# Producto 20711 - shape inválido: (0, 211), saltando
# Producto 20713 - shape inválido: (0, 211), saltando
# Producto 20714 - shape inválido: (0, 211), saltando
# Producto 20715 - shape inválido: (0, 211), saltando
# Producto 20719 - shape inválido: (0, 211), saltando
# Producto 20720 - shape inválido: (0, 211), saltando
# Producto 20721 - shape inválido: (0, 211), saltando
# Producto 20724 - shape inválido: (0, 211), saltando
# Producto 20729 - shape inválido: (0, 211), saltando
# Producto 20730 - shape inválido: (0, 211), saltando
# Producto 20732 - shape inválido: (0, 211), saltando
# Producto 20733 - shape inválido: (0, 211), saltando
# Producto 20735 - shape inválido: (0, 211), saltando
# Producto 20737 - shape inválido: (0, 211), saltando
# Producto 20739 - shape inválido: (0, 211), saltando
# Producto 20741 - shape inválido: (0, 211), saltando
# Producto 20742 - shape inválido: (0, 211), saltando
# Producto 20743 - shape inválido: (0, 211), saltando
# Producto 20744 - shape inválido: (0, 211), saltando
# Producto 20745 - shape inválido: (0, 211), saltando
# Producto 20746 - shape inválido: (0, 211), saltando
# Producto 20749 - shape inválido: (0, 211), saltando
# Producto 20750 - shape inválido: (0, 211), saltando
# Producto 20751 - shape inválido: (0, 211), saltando
# Producto 20754 - shape inválido: (0, 211), saltando
# Producto 20756 - shape inválido: (0, 211), saltando
# Producto 20757 - shape inválido: (0, 211), saltando
# Producto 20758 - shape inválido: (0, 211), saltando
# Producto 20759 - shape inválido: (0, 211), saltando
# Producto 20761 - shape inválido: (0, 211), saltando
# Producto 20762 - shape inválido: (0, 211), saltando
# Producto 20765 - shape inválido: (0, 211), saltando
# Producto 20768 - shape inválido: (0, 211), saltando
# Producto 20771 - shape inválido: (0, 211), saltando
# Producto 20772 - shape inválido: (0, 211), saltando
# Producto 20773 - shape inválido: (0, 211), saltando
# Producto 20774 - shape inválido: (0, 211), saltando
# Producto 20775 - shape inválido: (0, 211), saltando
# Producto 20777 - shape inválido: (0, 211), saltando
# Producto 20781 - shape inválido: (0, 211), saltando
# Producto 20783 - shape inválido: (0, 211), saltando
# Producto 20785 - shape inválido: (0, 211), saltando
# Producto 20786 - shape inválido: (0, 211), saltando
# Producto 20788 - shape inválido: (0, 211), saltando
# Producto 20789 - shape inválido: (0, 211), saltando
# Producto 20793 - shape inválido: (0, 211), saltando
# Producto 20795 - shape inválido: (0, 211), saltando
# Producto 20800 - shape inválido: (0, 211), saltando
# Producto 20801 - shape inválido: (0, 211), saltando
# Producto 20802 - shape inválido: (0, 211), saltando
# Producto 20803 - shape inválido: (0, 211), saltando
# Producto 20807 - shape inválido: (0, 211), saltando
# Producto 20809 - shape inválido: (0, 211), saltando
# Producto 20810 - shape inválido: (0, 211), saltando
# Producto 20811 - shape inválido: (0, 211), saltando
# Producto 20812 - shape inválido: (0, 211), saltando
# Producto 20815 - shape inválido: (0, 211), saltando
# Producto 20817 - shape inválido: (0, 211), saltando
# Producto 20818 - shape inválido: (0, 211), saltando
# Producto 20820 - shape inválido: (0, 211), saltando
# Producto 20822 - shape inválido: (0, 211), saltando
# Producto 20823 - shape inválido: (0, 211), saltando
# Producto 20824 - shape inválido: (0, 211), saltando
# Producto 20826 - shape inválido: (0, 211), saltando
# Producto 20827 - shape inválido: (0, 211), saltando
# Producto 20828 - shape inválido: (0, 211), saltando
# Producto 20830 - shape inválido: (0, 211), saltando
# Producto 20831 - shape inválido: (0, 211), saltando
# Producto 20832 - shape inválido: (0, 211), saltando
# Producto 20835 - shape inválido: (0, 211), saltando
# Producto 20838 - shape inválido: (0, 211), saltando
# Producto 20840 - shape inválido: (0, 211), saltando
# Producto 20843 - shape inválido: (0, 211), saltando
# Producto 20845 - shape inválido: (0, 211), saltando
# Producto 20846 - shape inválido: (0, 211), saltando
# Producto 20847 - shape inválido: (0, 211), saltando
# Producto 20849 - shape inválido: (0, 211), saltando
# Producto 20852 - shape inválido: (0, 211), saltando
# Producto 20853 - shape inválido: (0, 211), saltando
# Producto 20855 - shape inválido: (0, 211), saltando
# Producto 20859 - shape inválido: (0, 211), saltando
# Producto 20862 - shape inválido: (0, 211), saltando
# Producto 20863 - shape inválido: (0, 211), saltando
# Producto 20864 - shape inválido: (0, 211), saltando
# Producto 20865 - shape inválido: (0, 211), saltando
# Producto 20870 - shape inválido: (0, 211), saltando
# Producto 20877 - shape inválido: (0, 211), saltando
# Producto 20878 - shape inválido: (0, 211), saltando
# Producto 20879 - shape inválido: (0, 211), saltando
# Producto 20882 - shape inválido: (0, 211), saltando
# Producto 20883 - shape inválido: (0, 211), saltando
# Producto 20885 - shape inválido: (0, 211), saltando
# Producto 20886 - shape inválido: (0, 211), saltando
# Producto 20892 - shape inválido: (0, 211), saltando
# Producto 20894 - shape inválido: (0, 211), saltando
# Producto 20899 - shape inválido: (0, 211), saltando
# Producto 20901 - shape inválido: (0, 211), saltando
# Producto 20902 - shape inválido: (0, 211), saltando
# Producto 20904 - shape inválido: (0, 211), saltando
# Producto 20906 - shape inválido: (0, 211), saltando
# Producto 20907 - shape inválido: (0, 211), saltando
# Producto 20908 - shape inválido: (0, 211), saltando
# Producto 20910 - shape inválido: (0, 211), saltando
# Producto 20912 - shape inválido: (0, 211), saltando
# Producto 20913 - shape inválido: (0, 211), saltando
# Producto 20914 - shape inválido: (0, 211), saltando
# Producto 20917 - shape inválido: (0, 211), saltando
# Producto 20919 - shape inválido: (0, 211), saltando
# Producto 20920 - shape inválido: (0, 211), saltando
# Producto 20922 - shape inválido: (0, 211), saltando
# Producto 20924 - shape inválido: (0, 211), saltando
# Producto 20925 - shape inválido: (0, 211), saltando
# Producto 20927 - shape inválido: (0, 211), saltando
# Producto 20928 - shape inválido: (0, 211), saltando
# Producto 20931 - shape inválido: (0, 211), saltando
# Producto 20932 - shape inválido: (0, 211), saltando
# Producto 20933 - shape inválido: (0, 211), saltando
# Producto 20936 - shape inválido: (0, 211), saltando
# Producto 20937 - shape inválido: (0, 211), saltando
# Producto 20941 - shape inválido: (0, 211), saltando
# Producto 20942 - shape inválido: (0, 211), saltando
# Producto 20945 - shape inválido: (0, 211), saltando
# Producto 20946 - shape inválido: (0, 211), saltando
# Producto 20947 - shape inválido: (0, 211), saltando
# Producto 20948 - shape inválido: (0, 211), saltando
# Producto 20949 - shape inválido: (0, 211), saltando
# Producto 20951 - shape inválido: (0, 211), saltando
# Producto 20953 - shape inválido: (0, 211), saltando
# Producto 20956 - shape inválido: (0, 211), saltando
# Producto 20957 - shape inválido: (0, 211), saltando
# Producto 20961 - shape inválido: (0, 211), saltando
# Producto 20962 - shape inválido: (0, 211), saltando
# Producto 20965 - shape inválido: (0, 211), saltando
# Producto 20966 - shape inválido: (0, 211), saltando
# Producto 20967 - shape inválido: (0, 211), saltando
# Producto 20968 - shape inválido: (0, 211), saltando
# Producto 20970 - shape inválido: (0, 211), saltando
# Producto 20975 - shape inválido: (0, 211), saltando
# Producto 20976 - shape inválido: (0, 211), saltando
# Producto 20982 - shape inválido: (0, 211), saltando
# Producto 20985 - shape inválido: (0, 211), saltando
# Producto 20986 - shape inválido: (0, 211), saltando
# Producto 20987 - shape inválido: (0, 211), saltando
# Producto 20990 - shape inválido: (0, 211), saltando
# Producto 20991 - shape inválido: (0, 211), saltando
# Producto 20994 - shape inválido: (0, 211), saltando
# Producto 20995 - shape inválido: (0, 211), saltando
# Producto 20996 - shape inválido: (0, 211), saltando
# Producto 20997 - shape inválido: (0, 211), saltando
# Producto 21001 - shape inválido: (0, 211), saltando
# Producto 21003 - shape inválido: (0, 211), saltando
# Producto 21006 - shape inválido: (0, 211), saltando
# Producto 21007 - shape inválido: (0, 211), saltando
# Producto 21008 - shape inválido: (0, 211), saltando
# Producto 21014 - shape inválido: (0, 211), saltando
# Producto 21016 - shape inválido: (0, 211), saltando
# Producto 21022 - shape inválido: (0, 211), saltando
# Producto 21024 - shape inválido: (0, 211), saltando
# Producto 21027 - shape inválido: (0, 211), saltando
# Producto 21028 - shape inválido: (0, 211), saltando
# Producto 21032 - shape inválido: (0, 211), saltando
# Producto 21033 - shape inválido: (0, 211), saltando
# Producto 21034 - shape inválido: (0, 211), saltando
# Producto 21035 - shape inválido: (0, 211), saltando
# Producto 21037 - shape inválido: (0, 211), saltando
# Producto 21038 - shape inválido: (0, 211), saltando
# Producto 21039 - shape inválido: (0, 211), saltando
# Producto 21040 - shape inválido: (0, 211), saltando
# Producto 21042 - shape inválido: (0, 211), saltando
# Producto 21044 - shape inválido: (0, 211), saltando
# Producto 21048 - shape inválido: (0, 211), saltando
# Producto 21049 - shape inválido: (0, 211), saltando
# Producto 21055 - shape inválido: (0, 211), saltando
# Producto 21056 - shape inválido: (0, 211), saltando
# Producto 21057 - shape inválido: (0, 211), saltando
# Producto 21058 - shape inválido: (0, 211), saltando
# Producto 21064 - shape inválido: (0, 211), saltando
# Producto 21065 - shape inválido: (0, 211), saltando
# Producto 21073 - shape inválido: (0, 211), saltando
# Producto 21074 - shape inválido: (0, 211), saltando
# Producto 21077 - shape inválido: (0, 211), saltando
# Producto 21079 - shape inválido: (0, 211), saltando
# Producto 21080 - shape inválido: (0, 211), saltando
# Producto 21084 - shape inválido: (0, 211), saltando
# Producto 21086 - shape inválido: (0, 211), saltando
# Producto 21087 - shape inválido: (0, 211), saltando
# Producto 21088 - shape inválido: (0, 211), saltando
# Producto 21092 - shape inválido: (0, 211), saltando
# Producto 21093 - shape inválido: (0, 211), saltando
# Producto 21097 - shape inválido: (0, 211), saltando
# Producto 21099 - shape inválido: (0, 211), saltando
# Producto 21105 - shape inválido: (0, 211), saltando
# Producto 21109 - shape inválido: (0, 211), saltando
# Producto 21110 - shape inválido: (0, 211), saltando
# Producto 21111 - shape inválido: (0, 211), saltando
# Producto 21112 - shape inválido: (0, 211), saltando
# Producto 21114 - shape inválido: (0, 211), saltando
# Producto 21118 - shape inválido: (0, 211), saltando
# Producto 21119 - shape inválido: (0, 211), saltando
# Producto 21126 - shape inválido: (0, 211), saltando
# Producto 21129 - shape inválido: (0, 211), saltando
# Producto 21131 - shape inválido: (0, 211), saltando
# Producto 21135 - shape inválido: (0, 211), saltando
# Producto 21140 - shape inválido: (0, 211), saltando
# Producto 21142 - shape inválido: (0, 211), saltando
# Producto 21144 - shape inválido: (0, 211), saltando
# Producto 21146 - shape inválido: (0, 211), saltando
# Producto 21153 - shape inválido: (0, 211), saltando
# Producto 21154 - shape inválido: (0, 211), saltando
# Producto 21155 - shape inválido: (0, 211), saltando
# Producto 21157 - shape inválido: (0, 211), saltando
# Producto 21159 - shape inválido: (0, 211), saltando
# Producto 21163 - shape inválido: (0, 211), saltando
# Producto 21164 - shape inválido: (0, 211), saltando
# Producto 21167 - shape inválido: (0, 211), saltando
# Producto 21168 - shape inválido: (0, 211), saltando
# Producto 21170 - shape inválido: (0, 211), saltando
# Producto 21171 - shape inválido: (0, 211), saltando
# Producto 21176 - shape inválido: (0, 211), saltando
# Producto 21179 - shape inválido: (0, 211), saltando
# Producto 21180 - shape inválido: (0, 211), saltando
# Producto 21182 - shape inválido: (0, 211), saltando
# Producto 21184 - shape inválido: (0, 211), saltando
# Producto 21190 - shape inválido: (0, 211), saltando
# Producto 21191 - shape inválido: (0, 211), saltando
# Producto 21192 - shape inválido: (0, 211), saltando
# Producto 21194 - shape inválido: (0, 211), saltando
# Producto 21196 - shape inválido: (0, 211), saltando
# Producto 21200 - shape inválido: (0, 211), saltando
# Producto 21201 - shape inválido: (0, 211), saltando
# Producto 21202 - shape inválido: (0, 211), saltando
# Producto 21207 - shape inválido: (0, 211), saltando
# Producto 21209 - shape inválido: (0, 211), saltando
# Producto 21212 - shape inválido: (0, 211), saltando
# Producto 21214 - shape inválido: (0, 211), saltando
# Producto 21218 - shape inválido: (0, 211), saltando
# Producto 21222 - shape inválido: (0, 211), saltando
# Producto 21224 - shape inválido: (0, 211), saltando
# Producto 21226 - shape inválido: (0, 211), saltando
# Producto 21227 - shape inválido: (0, 211), saltando
# Producto 21233 - shape inválido: (0, 211), saltando
# Producto 21244 - shape inválido: (0, 211), saltando
# Producto 21245 - shape inválido: (0, 211), saltando
# Producto 21246 - shape inválido: (0, 211), saltando
# Producto 21248 - shape inválido: (0, 211), saltando
# Producto 21252 - shape inválido: (0, 211), saltando
# Producto 21256 - shape inválido: (0, 211), saltando
# Producto 21259 - shape inválido: (0, 211), saltando
# Producto 21262 - shape inválido: (0, 211), saltando
# Producto 21263 - shape inválido: (0, 211), saltando
# Producto 21265 - shape inválido: (0, 211), saltando
# Producto 21266 - shape inválido: (0, 211), saltando
# Producto 21267 - shape inválido: (0, 211), saltando
# Producto 21276 - shape inválido: (0, 211), saltando

# %%
print(f"Cantidad de productos listos para predecir: {len(X_seq_pred)}")
# Out:
# Cantidad de productos listos para predecir: 779

# %%
print(df_train.columns.tolist())
# Out:
# ['PERIODO', 'MES_SIN', 'MES_COS', 'ID_CAT1', 'ID_CAT2', 'ID_CAT3', 'ID_BRAND', 'SKU_SIZE', 'PRODUCT_ID', 'MES_PROBLEMATICO', 'IS_FEBRERO', 'ESTOY_PREDICIENDO_FEBRERO', 'CAIDA_ABRUPTA', 'CLASE_LOG1P_Z', 'PRODUCT_RANK_BIN', 'ORDINAL_Z', 'ANIO_Z', 'MES_Z', 'TRIMESTRE_Z', 'PRODUCT_ID_Z', 'TN_Z', 'PROM_ULT_3_FEBREROS_Z', 'DIF_TN_VS_FEBREROS_ULT_3_Z', 'TN_MAX_HISTORICO_Z', 'TN_DIST_A_MAX_HIST_Z', 'TN_RATIO_VS_MAX_HIST_Z', 'TN_MEAN_03_Z', 'PENDIENTE_TENDENCIA_3_Z', 'TN_EWMA_03_Z', 'TN_MEDIAN_03_Z', 'TN_MIN_03_Z', 'TN_MAX_03_Z', 'TN_STD_03_Z', 'TN_SKEW_03_Z', 'TN_KURT_03_Z', 'TN_GROWTH_03_Z', 'TN_IQR_03_Z', 'TN_SUM_03_Z', 'TN_COUNT_POS_03_Z', 'TN_PCT_ZERO_03_Z', 'TN_LAST_03_Z', 'TN_LAST_DIFF_03_Z', 'TN_COEF_VAR_3_Z', 'TN_MAXMIN_RATIO_3_Z', 'TN_RANGO_3_Z', 'TN_RANGO_REL_3_Z', 'TN_LAST_VS_MEDIAN_3_Z', 'TN_CHANGE_PREV_WINDOW_3_Z', 'TN_ZEROS_END_3_Z', 'TN_LAST_PCT_SUM_3_Z', 'TN_PCT90_3_Z', 'TN_PCT10_3_Z', 'TN_PCT_WIDTH_3_Z', 'TN_MINUS_MEAN_03_Z', 'TN_MINUS_MEDIAN_03_Z', 'TN_MINUS_EWMA_03_Z', 'TN_OVER_MEAN_03_Z', 'TN_OVER_MEDIAN_03_Z', 'TN_OVER_EWMA_03_Z', 'TN_MEAN_06_Z', 'PENDIENTE_TENDENCIA_6_Z', 'TN_EWMA_06_Z', 'TN_MEDIAN_06_Z', 'TN_MIN_06_Z', 'TN_MAX_06_Z', 'TN_STD_06_Z', 'TN_SKEW_06_Z', 'TN_KURT_06_Z', 'TN_GROWTH_06_Z', 'TN_IQR_06_Z', 'TN_SUM_06_Z', 'TN_COUNT_POS_06_Z', 'TN_PCT_ZERO_06_Z', 'TN_LAST_06_Z', 'TN_LAST_DIFF_06_Z', 'TN_COEF_VAR_6_Z', 'TN_MAXMIN_RATIO_6_Z', 'TN_RANGO_6_Z', 'TN_RANGO_REL_6_Z', 'TN_LAST_VS_MEDIAN_6_Z', 'TN_CHANGE_PREV_WINDOW_6_Z', 'TN_ZEROS_END_6_Z', 'TN_LAST_PCT_SUM_6_Z', 'TN_PCT90_6_Z', 'TN_PCT10_6_Z', 'TN_PCT_WIDTH_6_Z', 'TN_MINUS_MEAN_06_Z', 'TN_MINUS_MEDIAN_06_Z', 'TN_MINUS_EWMA_06_Z', 'TN_OVER_MEAN_06_Z', 'TN_OVER_MEDIAN_06_Z', 'TN_OVER_EWMA_06_Z', 'TN_MEAN_09_Z', 'PENDIENTE_TENDENCIA_9_Z', 'TN_EWMA_09_Z', 'TN_MEDIAN_09_Z', 'TN_MIN_09_Z', 'TN_MAX_09_Z', 'TN_STD_09_Z', 'TN_SKEW_09_Z', 'TN_KURT_09_Z', 'TN_GROWTH_09_Z', 'TN_IQR_09_Z', 'TN_SUM_09_Z', 'TN_COUNT_POS_09_Z', 'TN_PCT_ZERO_09_Z', 'TN_LAST_09_Z', 'TN_LAST_DIFF_09_Z', 'TN_COEF_VAR_9_Z', 'TN_MAXMIN_RATIO_9_Z', 'TN_RANGO_9_Z', 'TN_RANGO_REL_9_Z', 'TN_LAST_VS_MEDIAN_9_Z', 'TN_CHANGE_PREV_WINDOW_9_Z', 'TN_ZEROS_END_9_Z', 'TN_LAST_PCT_SUM_9_Z', 'TN_PCT90_9_Z', 'TN_PCT10_9_Z', 'TN_PCT_WIDTH_9_Z', 'TN_MINUS_MEAN_09_Z', 'TN_MINUS_MEDIAN_09_Z', 'TN_MINUS_EWMA_09_Z', 'TN_OVER_MEAN_09_Z', 'TN_OVER_MEDIAN_09_Z', 'TN_OVER_EWMA_09_Z', 'TN_MEAN_12_Z', 'PENDIENTE_TENDENCIA_12_Z', 'TN_EWMA_12_Z', 'TN_MEDIAN_12_Z', 'TN_MIN_12_Z', 'TN_MAX_12_Z', 'TN_STD_12_Z', 'TN_SKEW_12_Z', 'TN_KURT_12_Z', 'TN_GROWTH_12_Z', 'TN_IQR_12_Z', 'TN_SUM_12_Z', 'TN_COUNT_POS_12_Z', 'TN_PCT_ZERO_12_Z', 'TN_LAST_12_Z', 'TN_LAST_DIFF_12_Z', 'TN_COEF_VAR_12_Z', 'TN_MAXMIN_RATIO_12_Z', 'TN_RANGO_12_Z', 'TN_RANGO_REL_12_Z', 'TN_LAST_VS_MEDIAN_12_Z', 'TN_CHANGE_PREV_WINDOW_12_Z', 'TN_ZEROS_END_12_Z', 'TN_LAST_PCT_SUM_12_Z', 'TN_PCT90_12_Z', 'TN_PCT10_12_Z', 'TN_PCT_WIDTH_12_Z', 'TN_MINUS_MEAN_12_Z', 'TN_MINUS_MEDIAN_12_Z', 'TN_MINUS_EWMA_12_Z', 'TN_OVER_MEAN_12_Z', 'TN_OVER_MEDIAN_12_Z', 'TN_OVER_EWMA_12_Z', 'TN_MEAN_18_Z', 'PENDIENTE_TENDENCIA_18_Z', 'TN_EWMA_18_Z', 'TN_MEDIAN_18_Z', 'TN_MIN_18_Z', 'TN_MAX_18_Z', 'TN_STD_18_Z', 'TN_SKEW_18_Z', 'TN_KURT_18_Z', 'TN_GROWTH_18_Z', 'TN_IQR_18_Z', 'TN_SUM_18_Z', 'TN_COUNT_POS_18_Z', 'TN_PCT_ZERO_18_Z', 'TN_LAST_18_Z', 'TN_LAST_DIFF_18_Z', 'TN_COEF_VAR_18_Z', 'TN_MAXMIN_RATIO_18_Z', 'TN_RANGO_18_Z', 'TN_RANGO_REL_18_Z', 'TN_LAST_VS_MEDIAN_18_Z', 'TN_CHANGE_PREV_WINDOW_18_Z', 'TN_ZEROS_END_18_Z', 'TN_LAST_PCT_SUM_18_Z', 'TN_PCT90_18_Z', 'TN_PCT10_18_Z', 'TN_PCT_WIDTH_18_Z', 'TN_MINUS_MEAN_18_Z', 'TN_MINUS_MEDIAN_18_Z', 'TN_MINUS_EWMA_18_Z', 'TN_OVER_MEAN_18_Z', 'TN_OVER_MEDIAN_18_Z', 'TN_OVER_EWMA_18_Z', 'TN_LAG_03_Z', 'TN_DELTA_03_Z', 'TN_LAG_06_Z', 'TN_DELTA_06_Z', 'TN_LAG_09_Z', 'TN_DELTA_09_Z', 'TN_LAG_12_Z', 'TN_DELTA_12_Z', 'TN_LAG_18_Z', 'TN_DELTA_18_Z', 'TN_COUNT_ZERO_03_Z', 'TN_SIGN_CHANGES_03_Z', 'TN_COEF_VAR_03_Z', 'TN_OUTLIER_PROP_03_Z', 'TN_PCT_POS_03_Z', 'TN_COUNT_ZERO_06_Z', 'TN_SIGN_CHANGES_06_Z', 'TN_COEF_VAR_06_Z', 'TN_OUTLIER_PROP_06_Z ...

# %%
import numpy as np
scaler_y = joblib.load('scaler_y_CLASE_LOG1P.joblib')
# 1. Media histórica de CLASE_LOG1P_Z por producto (en df_train)
medias_log1p_z = df_train.groupby('PRODUCT_ID')['CLASE_LOG1P_Z'].mean().to_dict()

# 2. Para los productos sin historia:
# Arma array y deshace el Z-score usando el scaler_y
valores_z = np.array([medias_log1p_z.get(prod, 0) for prod in sin_historia]).reshape(-1, 1)
# Deshacer z-score: vuelve a log1p(TN)
valores_log1p = scaler_y.inverse_transform(valores_z).flatten()
# Vuelve a TN real
valores_tn = np.expm1(valores_log1p)

# 3. Resultado final como dict {PRODUCT_ID: TN_predicho}
predicciones_simple = dict(zip(list(sin_historia), valores_tn))

display(predicciones_simple)
# Out:
# {20001: 1400.6702005677594}
